# %% [markdown]
# ## Mutual Information in regression
#
# Estimate mutual information for a continuous target variable.
#
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
#
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances.
#
#
# It can be used for univariate features selection.
#
# **I(X;Y)=H(X)-H(X|Y) where I(X:Y)**

# %%
import pandas as pd

# %%
housing_df = pd.read_csv('loan.csv')

# %%
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#we have to choose the best features
numeric_list = ['int16','int32','int64','float16','float32','float64']
numerical_cols = list(housing_df.select_dtypes(include=numeric_list).columns)

# %%
numerical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
housing_df=housing_df[numerical_cols]

# %%
housing_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
#
# [5 rows x 38 columns]

# %%
housing_df.drop(labels=['Id'],axis=1)
# Out:
#       MSSubClass  LotFrontage  LotArea  ...  MoSold  YrSold  SalePrice
# 0             60         65.0     8450  ...       2    2008     208500
# 1             20         80.0     9600  ...       5    2007     181500
# 2             60         68.0    11250  ...       9    2008     223500
# 3             70         60.0     9550  ...       2    2006     140000
# 4             60         84.0    14260  ...      12    2008     250000
# ...          ...          ...      ...  ...     ...     ...        ...
# 1455          60         62.0     7917  ...       8    2007     175000
# 1456          20         85.0    13175  ...       2    2010     210000
# 1457          70         66.0     9042  ...       5    2010     266500
# 1458          20         68.0     9717  ...       4    2010     142125
# 1459          20         75.0     9937  ...       6    2008     147500
#
# [1460 rows x 37 columns]

# %%
x= housing_df.drop(labels=['SalePrice'],axis=1)
y=housing_df['SalePrice']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  ...  PoolArea  MiscVal  MoSold  YrSold
# 64      65          60          NaN     9375  ...         0        0       2    2009
# 682    683         120          NaN     2887  ...         0        0      11    2008
# 960    961          20         50.0     7207  ...         0        0       2    2010
# 1384  1385          50         60.0     9060  ...         0        0      10    2009
# 1100  1101          30         60.0     8400  ...         0        0       1    2009
# ...    ...         ...          ...      ...  ...       ...      ...     ...     ...
# 763    764          60         82.0     9430  ...         0        0       7    2009
# 835    836          20         60.0     9600  ...         0        0       2    2010
# 1216  1217          90         68.0     8930  ...         0        0       4    2010
# 559    560         120          NaN     3196  ...         0        0      10    2006
# ...

# %%
x_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression
mutual_info = mutual_info_regression(x_train.fillna(0),y_train)
mutual_info
# Out:
# array([0.        , 0.25128437, 0.20504362, 0.16573924, 0.52775078,
#        0.10128326, 0.35343539, 0.2397367 , 0.10417609, 0.15791348,
#        0.        , 0.10872826, 0.38065311, 0.31110983, 0.22496944,
#        0.01393527, 0.48080784, 0.03282698, 0.00407347, 0.26832733,
#        0.07959608, 0.04606543, 0.0199386 , 0.17781354, 0.17971268,
#        0.26747499, 0.36487605, 0.37114925, 0.06787278, 0.1736341 ,
#        0.01261327, 0.00589291, 0.0062426 , 0.00870203, 0.00445458,
#        0.        , 0.01095142])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.527751
# GrLivArea        0.480808
# TotalBsmtSF      0.380653
# GarageArea       0.371149
# GarageCars       0.364876
# YearBuilt        0.353435
# 1stFlrSF         0.311110
# FullBath         0.268327
# GarageYrBlt      0.267475
# MSSubClass       0.251284
# YearRemodAdd     0.239737
# 2ndFlrSF         0.224969
# LotFrontage      0.205044
# Fireplaces       0.179713
# TotRmsAbvGrd     0.177814
# OpenPorchSF      0.173634
# LotArea          0.165739
# BsmtFinSF1       0.157913
# BsmtUnfSF        0.108728
# MasVnrArea       0.104176
# OverallCond      0.101283
# HalfBath         0.079596
# WoodDeckSF       0.067873
# BedroomAbvGr     0.046065
# BsmtFullBath     0.032827
# KitchenAbvGr     0.019939
# LowQualFinSF     0.013935
# EnclosedPorch    0.012613
# YrSold           0.010951
# PoolArea         0.008702
# ScreenPorch      0.006243
# 3SsnPorch        0.005893
# MiscVal          0.004455
# BsmtHalfBath     0.004073
# BsmtFinSF2       0.000000
# ...

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20,10))

# %%
from sklearn.feature_selection import SelectPercentile

# %%
top_cols = SelectPercentile(mutual_info_regression,percentile=20) #top 20 percentile
top_cols.fit(x_train.fillna(0),y_train)
# Out:
# SelectPercentile(percentile=20,
#                  score_func=<function mutual_info_regression at 0x7f1064350dd0>)

# %%
x_train.columns[top_cols.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'FullBath', 'GarageCars', 'GarageArea'],
#       dtype='object')
